# %%
pip freeze
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip freeze
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import tweepy 
import pandas as pd

# %%
consumer_key = "cfhtDBkVFfC4VyXtlkSUOpLe8"
consumer_secret = "eX7BAGWbnnptAcDN7YqXUb1uoQ8TLO7Zdsx48CIxt1FBgQ9Hiv"
access_key = "1138316071910297600-1cwVGr1m9Me0IYos4ONGpbIF0Dcol2"
access_secret = "udR3MwXueqWz50FoEIfshXH4WbNsfZ4CJWQFOaWxk8ksu"

# %%
def get_tweets(username): 
          
        # Authorization to consumer key and consumer secret 
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
  
        # Access to user's access key and access secret 
        auth.set_access_token(access_key, access_secret) 
  
        # Calling api 
        api = tweepy.API(auth) 
  
        # 200 tweets to be extracted 
        number_of_tweets=2000
        tweets = api.user_timeline(screen_name=username) 
  
        # Empty Array 
        tmp=[]  
  
        # create array of tweet information: username,  
        # tweet id, date/time, text 
        import csv
        csvfile=open('tweets.csv','a')
        csvwriter = csv.writer(csvfile)
        tweets_for_csv = [tweet.text for tweet in tweets] # CSV file created  
        for j in tweets_for_csv: 
  
            # Appending tweets to the empty array tmp 
            tmp.append(j)  
            csvwriter.writerow([j.encode('utf-8')])
  
        # Printing the tweets 
        print(tmp) 
        
       
        csvfile.close()
  
  
# Driver code 
if __name__ == '__main__': 
  
    # Here goes the twitter handle for the user 
    # whose tweets are to be extracted. 
    get_tweets("@deepikapadukone")
# Out:
# ['RT @TLLLFoundation: Burnout is not permanent and can be overcome with the correct course of action. #Burnout https://t.co/q8pnLOC5to', 'LOVE!!!\U0001f970\U0001f970\U0001f970 https://t.co/pMSWXZHuBY', 'RT @voguemagazine: Deepika Padukone, Kendall Jenner, and more attended the fundraising dinner for the Youth Anxiety Center. https://t.co/Fu…', '&amp; on to the next...Thank You @kabirkhankk for this incredible honour! #RomiDev #Day1 @83thefilm @RanveerOfficial https://t.co/yZ13MFpRN1', '&amp; on to the next...Thank You @kabirkhankk for this incredible honour! #RomiDev #Day1 @83thefilm @RanveerOfficial https://t.co/ERz7XhLdTX', '&amp; on to the next...Thank You @kabirkhankk for this incredible honour! #RomiDev #Day1 @83thefilm @RanveerOfficial https://t.co/lLB8kcmbVy', 'A little late in the day but I couldn’t agree more Aloo... her honesty &amp; insight really amazes me...love you both!… https://t.co/CW9rNB72Gt', 'RT @JustJared: Amber Heard &amp; Deepika Padukone hit the carpet at #Cannes2019 looking stunning! See the pics here: https://t.co/bS3Se8K0MK', 'RT @voguemagazine: Currently on her fourth trip to the festival, @deepikapadukone has mastered looking flawless on and off its red carpets.…', '🙌🏽 @harpersbazaarus https://t.co/EMew4jZ6je', 'Ab Bas!Now back to  Chhapaak &amp; @RanveerOfficial ...❤️ https://t.co/GsJzIdQEl2', '❤️ @Tutejajoginder https://t.co/DDq2jZlFjU', 'honestly...I’m torn between staying  and going back home!😝 https://t.co/4mBJ5zyCfn', 'come with me smallie...il teach you!😘😘😘 @anishapadukone https://t.co/uBykJo3yca', 'congratulations &amp; all the best @RajeevMasand !❤️ https://t.co/HHj6qdT2GX', 'RT @JustJared: Deepika Padukone had a major fashion moment on the #MetGala red carpet! https://t.co/dhyfSlY4v2', 'RT @ManuVichare: #DeepikaPadukone #DeepikaAtMetGala #MetGala2019\u2060 \u2060 ...\n@deepikapadukone https://t.co/0ib6BYuSjg', 'this couldn’t make me happier...❤️ @ShebaSid https://t.co/I8ekPNsiuH', 'How we went about getting ready for The First Monday in May...Enjoy!💋 https://t.co/pxPrEiz2VC https://t.co/wjsQNlXnik', 'RT @eonlineasia: We need a moment because these Asian celebs look SO stunning on the Met Gala pink carpet 💯. Which is your favourite #MetGa…']

# %%
import nltk
import pandas as pd
dataset = pd.read_csv('tweets.csv','r',error_bad_lines=False)
# Out:
# b'Skipping line 5: expected 1 fields, saw 2\nSkipping line 7: expected 1 fields, saw 2\nSkipping line 11: expected 1 fields, saw 2\nSkipping line 23: expected 1 fields, saw 5\nSkipping line 27: expected 1 fields, saw 2\nSkipping line 29: expected 1 fields, saw 2\nSkipping line 31: expected 1 fields, saw 2\nSkipping line 37: expected 1 fields, saw 10\nSkipping line 39: expected 1 fields, saw 3\nSkipping line 41: expected 1 fields, saw 8\nSkipping line 47: expected 1 fields, saw 6\nSkipping line 49: expected 1 fields, saw 6\nSkipping line 51: expected 1 fields, saw 6\nSkipping line 53: expected 1 fields, saw 6\nSkipping line 55: expected 1 fields, saw 6\nSkipping line 59: expected 1 fields, saw 4\nSkipping line 61: expected 1 fields, saw 2\nSkipping line 63: expected 1 fields, saw 2\nSkipping line 65: expected 1 fields, saw 2\nSkipping line 69: expected 1 fields, saw 2\nSkipping line 71: expected 1 fields, saw 5\nSkipping line 73: expected 1 fields, saw 2\nSkipping line 75: expected 1 fields, saw 2\nSkipping line 77: expected 1 fields, saw 5\nSkipping line 79: expected 1 fields, saw 4\n'

# %%
pat=r'''#\w+'''
tokenizer = nltk.regexp_tokenize(str(dataset),pat)
tokenizer
# Out:
# []

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()
tokenizer=list(dict.fromkeys(tokenizer))
tokenizer
# Out:
# []

# %%
stemtoken=[]
for token in tokenizer:
    print(ps.stem(token))
    stemtoken.append(ps.stem(token))

# %%
from nltk import ngrams
n=3
ngrm=[]
res = ngrams(str(dataset).split(),n) 
for s in res:
    ngrm.append(s)
ngrm
# Out:
# [("b'Also", 'exquisite', 'display'),
#  ('exquisite', 'display', 'of'),
#  ('display', 'of', 'spo'),
#  ('of', 'spo', '\\'),
#  ('spo', '\\', '0'),
#  ('\\', '0', "b'G"),
#  ('0', "b'G", '1'),
#  ("b'G", '1', "b'Thank"),
#  ('1', "b'Thank", 'you'),
#  ("b'Thank", 'you', 'Patrick'),
#  ('you', 'Patrick', 'and'),
#  ('Patrick', 'and', 'Basu'),
#  ('and', 'Basu', 'for'),
#  ('Basu', 'for', 'the'),
#  ('for', 'the', 'amazing'),
#  ('the', 'amazing', 'w...'),
#  ('amazing', 'w...', '2'),
#  ('w...', '2', "b'Fi"),
#  ('2', "b'Fi", '3'),
#  ("b'Fi", '3', 'b"Happy'),
#  ('3', 'b"Happy', 'birthday'),
#  ('b"Happy', 'birthday', 'mahi'),
#  ('birthday', 'mahi', 'bhai'),
#  ('mahi', 'bhai', '@msdhoni.'),
#  ('bhai', '@msdhoni.', 'Very'),
#  ('@msdhoni.', 'Very', 'few'),
#  ('Very', 'few', '...'),
#  ('few', '...', '4'),
#  ('...', '4', "b'On"),
#  ('4', "b'On", 'to'),
#  ("b'On", 'to', 'the'),
#  ('to', 'the', 'semis'),
#  ('the', 'semis', 'now!'),
#  ('semis', 'now!', '\\xf0\\x9f\\x87\\xae\\xf0\\x9...'),
#  ('now!', '\\xf0\\x9f\\x87\\xae\\xf0\\x9...', '5'),
#  ('\\xf0\\x9f\\x87\\xae\\xf0\\x9...', '5', "b'Smiles"),
#  ('5', "b'Smiles", 'all'),
#  ("b'Smiles", 'all', 'a'),
#  ('all', 'a', '6'),
#  ('a', '6', "b'Was"),
#  ('6', "b'Was", 'fun'),
#  ("b'Was", 'fun', 'catching'),
#  ('fun', 'catching', 'up'),
#  ('catching', 'up', 'with'),
#  ('up', 'with', 'you'),
#  ('with', 'you', 'Ha'),
#  ('you', 'Ha', '7'),
#  ('Ha', '7', "b'M"),
#  ('7', "b'M", '8'),
#  ("b'M", '8', 'b"Wish'),
#  ('8', 'b"Wish', 'you'),
#  ('b"Wish', 'you', 'a'),
#  ('you', 'a', 'very'),
#  ('a', 'very', 'Happy'),
#  ('very', 'Happy', "B'day"),
#  ('Happy', "B'day", 'Bhajju'),
#  ("B'day", 'Bhajju', 'Pa.'),
#  ('Bhajju', 'Pa.', '\\xf0\\...'),
#  ('Pa.', '\\xf0\\...', '9'),
#  ('\\xf0\\...', '9', 'b"Wish'),
#  ('9', 'b"Wish', 'you'),
#  ('b"Wish', 'you', 'the'),
#  ('you', 'the', 'best'),
#  ('the', 'best', 'going'),
#  ('best', 'going', 'forward'),
#  ('going', 'forward', 'Ambati.'),
#  ('forward', 'Ambati.', "You'..."),
#  ('Ambati.', "You'...", '10'),
#  ("You'...", '10', 'b"Also'),
#  ('10', 'b"Also', 'would'),
#  ('b"Also', 'would', 'like'),
#  ('would', 'like', 'to'),
#  ('like', 'to', 'thank'),
#  ('to', 'thank', 'all'),
#  ('thank', 'all', 'our'),
#  ('all', 'our', 'fans'),
#  ('our', 'fans', 'for'),
#  ('fans', 'for', 'al...'),
#  ('for', 'al...', '11'),
#  ('al...', '11', "b'What"),
#  ('11', "b'What", 'a'),
#  ("b'What", 'a', 'unit.'),
#  ('a', 'unit.', 'We'),
#  ('unit.', 'We', 'ma'),
#  ('We', 'ma', '12'),
#  ('ma', '12', "b'\\xf0\\x9f\\x91\\x95\\xf0\\x9f\\x91\\x8c\\xf0\\x9f\\x91..."),
#  ('12', "b'\\xf0\\x9f\\x91\\x95\\xf0\\x9f\\x91\\x8c\\xf0\\x9f\\x91...", '13'),
#  ("b'\\xf0\\x9f\\x91\\x95\\xf0\\x9f\\x91\\x8c\\xf0\\x9f\\x91...",
#   '13',
#   "b'Belief"),
#  ('13', "b'Belief", 'is'),
#  ("b'Belief", 'is', 'a'),
#  ('is', 'a', 'beautiful'),
#  ('a', 'beautiful', 'gift.'),
#  ('beautiful', 'gift.', 'We'),
#  ('gift.', 'We', 'must'),
#  ('We', 'must', 'all'),
#  ('must', 'all', 'use'),
#  ('all', 'use', '...'),
#  ('use', '...', '14'),
#  ('...', '14', 'b"Don\'t'),
#  ('14', 'b"Don\'t', 'know'),
#  ('b"Don\'t', 'know', 'about'),
#  ('know', 'about', 'football,'),
#  ('about', 'football,', 'but'),
#  ('football,', 'but', 'Manchester'),
#  ('but', 'Manchester', 'wa...'),
#  ('Manchester', 'wa...', '15'),
#  ('wa...', '15', "b'Out"),
#  ('15', "b'Out", 'and'),
#  ("b'Out", 'and', 'about'),
#  ('and', 'about', 'in'),
#  ('about', 'in', 'mancheste'),
#  ('in', 'mancheste', '16'),
#  ('mancheste', '16', "b'Loved"),
#  ('16', "b'Loved", 'the'),
#  ("b'Loved", 'the', 'gold'),
#  ('the', 'gold', '&amp;'),
#  ('gold', '&amp;', 'white'),
#  ('&amp;', 'white', 'combination'),
#  ('white', 'combination', 'on'),
#  ('combination', 'on', 'th...'),
#  ('on', 'th...', '17'),
#  ('th...', '17', "b'No"),
#  ('17', "b'No", 'days'),
#  ("b'No", 'days', 'off'),
#  ('days', 'off', '\\xf0\\x9f\\x92\\xaa\\xf0\\x9f\\x8f\\x8b...'),
#  ('off', '\\xf0\\x9f\\x92\\xaa\\xf0\\x9f\\x8f\\x8b...', '18'),
#  ('\\xf0\\x9f\\x92\\xaa\\xf0\\x9f\\x8f\\x8b...', '18', "b'B"),
#  ('18', "b'B", '19'),
#  ("b'B", '19', "b'@E"),
#  ('19', "b'@E", '20'),
#  ("b'@E", '20', "b'@Vyyype"),
#  ('20', "b'@Vyyype", '21'),
#  ("b'@Vyyype", '21', "b'@jacksonhvisuals"),
#  ('21', "b'@jacksonhvisuals", 'Eve'),
#  ("b'@jacksonhvisuals", 'Eve', '22'),
#  ('Eve', '22', "b'@sa"),
#  ('22', "b'@sa", '23'),
#  ("b'@sa", '23', 'b"NEW'),
#  ('23', 'b"NEW', 'VIDEO'),
#  ('b"NEW', 'VIDEO', '-'),
#  ('VIDEO', '-', "What's"),
#  ('-', "What's", 'in'),
#  ("What's", 'in', 'my'),
#  ('in', 'my', 'Tech'),
#  ('my', 'Tech', 'Bag!'),
#  ('Tech', 'Bag!', '[2019]'),
#  ('Bag!', '[2019]', 'ht...'),
#  ('[2019]', 'ht...', '24'),
#  ('ht...', '24', "b'Uploading\\xe2\\x80\\xa6'"),
#  ('24', "b'Uploading\\xe2\\x80\\xa6'", '25'),
#  ("b'Uploading\\xe2\\x80\\xa6'", '25', "b'@ZacksJe"),
#  ('25', "b'@ZacksJe", '26'),
#  ("b'@ZacksJe", '26', "b'@thephysicsgi"),
#  ('26', "b'@thephysicsgi", '27'),
#  ("b'@thephysicsgi", '27', "b'@Cobinja"),
#  ('27', "b'@Cobinja", "Run.'"),
#  ("b'@Cobinja", "Run.'", '28'),
#  ("Run.'", '28', "b'@swoonbergh"),
#  ('28', "b'@swoonbergh", 'Stock,'),
#  ("b'@swoonbergh", 'Stock,', 'primary'),
#  ('Stock,', 'primary', "lens'"),
#  ('primary', "lens'", '29'),
#  ("lens'", '29', "b'@SnazzyQ"),
#  ('29', "b'@SnazzyQ", 'I'),
#  ("b'@SnazzyQ", 'I', 'keep'),
#  ('I', 'keep', 'a'),
#  ('keep', 'a', 'squeegie'),
#  ('a', 'squeegie', 'in'),
#  ('squeegie', 'in', 'my'),
#  ('in', 'my', 'ca'),
#  ('my', 'ca', '..'),
#  ('ca', '..', '...'),
#  ('..', '...', '48'),
#  ('...', '48', 'b"Ok'),
#  ('48', 'b"Ok', "I'm"),
#  ('b"Ok', "I'm", 'not'),
#  ("I'm", 'not', 'even'),
#  ('not', 'even', 'a'),
#  ('even', 'a', 'cat'),
#  ('a', 'cat', 'person'),
#  ('cat', 'person', 'but'),
#  ('person', 'but', 'honestly'),
#  ('but', 'honestly', 'th...'),
#  ('honestly', 'th...', '49'),
#  ('th...', '49', 'b\'"Being'),
#  ('49', 'b\'"Being', 'first'),
#  ('b\'"Being', 'first', "doesn\\'t"),
#  ('first', "doesn\\'t", 'matter'),
#  ("doesn\\'t", 'matter', 'if'),
#  ('matter', 'if', 'it'),
#  ('if', 'it', 'sucks"'),
#  ('it', 'sucks"', '-'),
#  ('sucks"', '-', '...'),
#  ('-', '...', '50'),
#  ('...', '50', "b'TWEETS"),
#  ('50', "b'TWEETS", 'BUT'),
#  ("b'TWEETS", 'BUT', 'WITH'),
#  ('BUT', 'WITH', "EDITING'"),
#  ('WITH', "EDITING'", '51'),
#  ("EDITING'", '51', 'b"@KTasterisk'),
#  ('51', 'b"@KTasterisk', 'I'),
#  ('b"@KTasterisk', 'I', "can't"),
#  ('I', "can't", 'disagree"'),
#  ("can't", 'disagree"', '52'),
#  ('disagree"', '52', "b'@abhishek1point0"),
#  ('52', "b'@abhishek1point0", 'This'),
#  ("b'@abhishek1point0", 'This', 'is'),
#  ('This', 'is', 'all'),
#  ('is', 'all', 'fantastic'),
#  ('all', 'fantastic', 'logic...'),
#  ('fantastic', 'logic...', '53'),
#  ('logic...', '53', "b'RT"),
#  ('53', "b'RT", '@zivbuzaglo:'),
#  ("b'RT", '@zivbuzaglo:', 'B'),
#  ('@zivbuzaglo:', 'B', '54'),
#  ('B', '54', "b'@supe"),
#  ('54', "b'@supe", '55'),
#  ("b'@supe", '55', "b'@SalahEl_Deen"),
#  ('55', "b'@SalahEl_Deen", "\\xf0\\x9f\\x98\\x85'"),
#  ("b'@SalahEl_Deen", "\\xf0\\x9f\\x98\\x85'", '56'),
#  ("\\xf0\\x9f\\x98\\x85'", '56', "b'NEW"),
#  ('56', "b'NEW", 'VIDEO'),
#  ("b'NEW", 'VIDEO', '-'),
#  ('VIDEO', '-', 'The'),
#  ('-', 'The', 'Last'),
#  ('The', 'Last', '(and'),
#  ('Last', '(and', 'Fi'),
#  ('(and', 'Fi', '57'),
#  ('Fi', '57', "b'\\xf0\\x9f\\x94\\xa5"),
#  ('57', "b'\\xf0\\x9f\\x94\\xa5", 'Uploading\\xe2\\x80\\xa6'),
#  ("b'\\xf0\\x9f\\x94\\xa5", 'Uploading\\xe2\\x80\\xa6', '\\xf0\\...'),
#  ('Uploading\\xe2\\x80\\xa6', '\\xf0\\...', '58'),
#  ('\\xf0\\...', '58', 'b"AirPower'),
#  ('58', 'b"AirPower', 'Award'),
#  ('b"AirPower', 'Award', '2019'),
#  ('Award', '2019', 'goes'),
#  ('2019', 'goes', 'to:'),
#  ('goes', 'to:', 'Bixby'),
#  ('to:', 'Bixby', 'speaker'),
#  ('Bixby', 'speaker', '\\...'),
#  ('speaker', '\\...', '59'),
#  ('\\...', '59', "b'Yes..."),
#  ('59', "b'Yes...", '3'),
#  ("b'Yes...", '3', 'films'),
#  ('3', 'films', 'and'),
#  ('films', 'and', 'a'),
#  ('and', 'a', 'webse'),
#  ('a', 'webse', '60'),
#  ('webse', '60', "b'A"),
#  ('60', "b'A", 'telugu'),
#  ("b'A", 'telugu', 'webse'),
#  ('telugu', 'webse', '61'),
#  ('webse', '61', "b'\\xf0\\x9f\\x98\\x82"),
#  ('61', "b'\\xf0\\x9f\\x98\\x82", 'so'),
#  ("b'\\xf0\\x9f\\x98\\x82", 'so', '62'),
#  ('so', '62', "b'Hi!'"),
#  ('62', "b'Hi!'", '63'),
#  ("b'Hi!'", '63', "b'RT"),
#  ('63', "b'RT", '@Acto'),
#  ("b'RT", '@Acto', '64'),
#  ('@Acto', '64', "b'@Da"),
#  ('64', "b'@Da", '65'),
#  ("b'@Da", '65', "b'I\\xe2\\x80\\x99m"),
#  ('65', "b'I\\xe2\\x80\\x99m", 'speechless!'),
#  ("b'I\\xe2\\x80\\x99m", 'speechless!', '\\xe2\\x9d\\xa4\\xef\\...'),
#  ('speechless!', '\\xe2\\x9d\\xa4\\xef\\...', '66'),
#  ('\\xe2\\x9d\\xa4\\xef\\...', '66', "b'RT"),
#  ('66', "b'RT", '@monaeltahawy:'),
#  ("b'RT", '@monaeltahawy:', 'Two'),
#  ('@monaeltahawy:', 'Two', 'lawye'),
#  ('Two', 'lawye', '67'),
#  ('lawye', '67', "b'Yes"),
#  ('67', "b'Yes", 'yes'),
#  ("b'Yes", 'yes', 'yes'),
#  ('yes', 'yes', 'yes'),
#  ('yes', 'yes', 'YESSSS!!!!'),
#  ('yes', 'YESSSS!!!!', 'https://t.co/iWLq...'),
#  ('YESSSS!!!!', 'https://t.co/iWLq...', '68'),
#  ('https://t.co/iWLq...', '68', "b'@p"),
#  ('68', "b'@p", '69'),
#  ("b'@p", '69', "b'Now"),
#  ('69', "b'Now", 'my'),
#  ("b'Now", 'my', 'mummy'),
#  ('my', 'mummy', 'will'),
#  ('mummy', 'will', 'not'),
#  ('will', 'not', 'be'),
#  ('not', 'be', 'able'),
#  ('be', 'able', 'to'),
#  ('able', 'to', 'say'),
#  ('to', 'say', '\\xe2\\x8...'),
#  ('say', '\\xe2\\x8...', '70'),
#  ('\\xe2\\x8...', '70', "b'Goodnight"),
#  ('70', "b'Goodnight", 'wo'),
#  ("b'Goodnight", 'wo', '71'),
#  ('wo', '71', "b'\\xf0\\x9f\\x92\\xab\\xf0\\x9f\\xa4\\x97"),
#  ('71', "b'\\xf0\\x9f\\x92\\xab\\xf0\\x9f\\xa4\\x97", '@Acto'),
#  ("b'\\xf0\\x9f\\x92\\xab\\xf0\\x9f\\xa4\\x97", '@Acto', '72'),
#  ('@Acto', '72', "b'@aadhavkk"),
#  ('72', "b'@aadhavkk", 'Next'),
#  ("b'@aadhavkk", 'Next', 'coming'),
#  ('Next', 'coming', 'week'),
#  ('coming', 'week', '\\xf0\\x9f\\x98\\x8b\\...'),
#  ('week', '\\xf0\\x9f\\x98\\x8b\\...', '73'),
#  ('\\xf0\\x9f\\x98\\x8b\\...', '73', "b'@RajaShanmuga77"),
#  ('73', "b'@RajaShanmuga77", '\\xf0\\x9f\\x92\\xab'),
#  ("b'@RajaShanmuga77", '\\xf0\\x9f\\x92\\xab', 'https://t.c...'),
#  ('\\xf0\\x9f\\x92\\xab', 'https://t.c...', '74'),
#  ('https://t.c...', '74', "b'Wow!"),
#  ('74', "b'Wow!", 'congratulations'),
#  ("b'Wow!", 'congratulations', 'and'),
#  ('congratulations', 'and', 'best'),
#  ('and', 'best', 'wishes'),
#  ('best', 'wishes', '@Actor_...'),
#  ('wishes', '@Actor_...', '75'),
#  ('@Actor_...', '75', "b'@pushpaignatius"),
#  ('75', "b'@pushpaignatius", '\\xf0\\x9f\\xa4\\x97\\xf0\\x9f\\xa4...'),
#  ("b'@pushpaignatius", '\\xf0\\x9f\\xa4\\x97\\xf0\\x9f\\xa4...', '76'),
#  ('\\xf0\\x9f\\xa4\\x97\\xf0\\x9f\\xa4...', '76', "b'Catch"),
#  ('76', "b'Catch", 'me'),
#  ("b'Catch", 'me', 'in'),
#  ('me', 'in', 'the'),
#  ('in', 'the', '7'),
#  ('the', '7', '&amp;'),
#  ('7', '&amp;', '8th'),
#  ('&amp;', '8th', 'episode...'),
#  ('8th', 'episode...', 'but'),
#  ('episode...', 'but', 'd...'),
#  ('but', 'd...', '77'),
#  ('d...', '77', "b'Ti"),
#  ('77', "b'Ti", 't'),
#  ("b'Ti", 't', 'ove'),
#  ('t', 'ove', '\\'),
#  ('ove', '\\', '0'),
#  ('\\', '0', 'eat'),
#  ('0', 'eat', 'show'),
#  ('eat', 'show', 'by'),
#  ('show', 'by', 'both'),
#  ('by', 'both', 'the'),
#  ('both', 'the', 'teams'),
#  ('the', 'teams', 'in'),
#  ('teams', 'in', 'the'),
#  ('in', 'the', '#CWC19Finals...'),
#  ('the', '#CWC19Finals...', '1'),
#  ('#CWC19Finals...', '1', 'NaN'),
#  ('1', 'NaN', '2'),
#  ('NaN', '2', 'stly'),
#  ('2', 'stly', 'I'),
#  ('stly', 'I', 'want'),
#  ('I', 'want', 'to'),
#  ('want', 'to', 'thank'),
#  ('to', 'thank', 'all'),
#  ('thank', 'all', 'ou'),
#  ('all', 'ou', '3'),
#  ('ou', '3', 'NaN'),
#  ('3', 'NaN', '4'),
#  ('NaN', '4', 'oud'),
#  ('4', 'oud', 'of'),
#  ('oud', 'of', 'the'),
#  ('of', 'the', 'cha'),
#  ('the', 'cha', '5'),
#  ('cha', '5', 'ound'),
#  ('5', 'ound', '\\xf0\\x9f\\x99\\x82.'),
#  ('ound', '\\xf0\\x9f\\x99\\x82.', 'Being'),
#  ('\\xf0\\x9f\\x99\\x82.', 'Being', 'able'),
#  ('Being', 'able', 'to'),
#  ('able', 'to', 'inspi'),
#  ('to', 'inspi', '6'),
#  ('inspi', '6', 'NaN'),
#  ('6', 'NaN', '7'),
#  ('NaN', '7', 'and'),
#  ('7', 'and', 'M'),
#  ('and', 'M', '8'),
#  ('M', '8', 'NaN'),
#  ('8', 'NaN', '9'),
#  ('NaN', '9', 'NaN'),
#  ('9', 'NaN', '10'),
#  ('NaN', '10', 'NaN'),
#  ('10', 'NaN', '11'),
#  ('NaN', '11', 'ch'),
#  ('11', 'ch', 'on.'),
#  ('ch', 'on.', 'Jai'),
#  ('on.', 'Jai', 'hind'),
#  ('Jai', 'hind', '\\xf0\\x9f\\x87\\xae\\xf0\\x9f\\x87\\x...'),
#  ('hind', '\\xf0\\x9f\\x87\\xae\\xf0\\x9f\\x87\\x...', '12'),
#  ('\\xf0\\x9f\\x87\\xae\\xf0\\x9f\\x87\\x...', '12', 'NaN'),
#  ('12', 'NaN', '13'),
#  ('NaN', '13', 'yone'),
#  ('13', 'yone', '\\xf0\\x9f\\xa4\\x9d\\xe2\\x9c\\x8c'),
#  ('yone', '\\xf0\\x9f\\xa4\\x9d\\xe2\\x9c\\x8c', 'https://t.co...'),
#  ('\\xf0\\x9f\\xa4\\x9d\\xe2\\x9c\\x8c', 'https://t.co...', '14'),
#  ('https://t.co...', '14', 'NaN'),
#  ('14', 'NaN', '15'),
#  ('NaN', '15', '\\xf0\\x9f\\x98\\x8e'),
#  ('15', '\\xf0\\x9f\\x98\\x8e', "https://t.co/QbcjS5VORD'"),
#  ('\\xf0\\x9f\\x98\\x8e', "https://t.co/QbcjS5VORD'", '16'),
#  ("https://t.co/QbcjS5VORD'", '16', 'icket'),
#  ('16', 'icket', 'has'),
#  ('icket', 'has', 'anothe'),
#  ('has', 'anothe', '17'),
#  ('anothe', '17', 'dwo'),
#  ('17', 'dwo', '18'),
#  ('dwo', '18', 'eakfast'),
#  ('18', 'eakfast', 'alongside'),
#  ('eakfast', 'alongside', 'some'),
#  ('alongside', 'some', 'good'),
#  ('some', 'good', 'fellas'),
#  ('good', 'fellas', '\\xf0\\x9f\\xa...'),
#  ('fellas', '\\xf0\\x9f\\xa...', '19'),
#  ('\\xf0\\x9f\\xa...', '19', 'ikTilden'),
#  ('19', 'ikTilden', 'I'),
#  ('ikTilden', 'I', 'take'),
#  ('I', 'take', 'matte'),
#  ('take', 'matte', 'black'),
#  ('matte', 'black', 'eve'),
#  ('black', 'eve', '20'),
#  ('eve', '20', 'The'),
#  ('20', 'The', 'c'),
#  ('The', 'c', '21'),
#  ('c', '21', 'yone'),
#  ('21', 'yone', 'knows'),
#  ('yone', 'knows', 'the'),
#  ('knows', 'the', 'thiccest'),
#  ('the', 'thiccest', 'lens'),
#  ('thiccest', 'lens', 'p'),
#  ('lens', 'p', '22'),
#  ('p', '22', 'adietschy'),
#  ('22', 'adietschy', 'Legit'),
#  ('adietschy', 'Legit', 'weighs'),
#  ('Legit', 'weighs', 'twice'),
#  ('weighs', 'twice', 'as'),
#  ('twice', 'as', 'much'),
#  ('as', 'much', 'as'),
#  ('much', 'as', 'the'),
#  ('as', 'the', 'ac...'),
#  ('the', 'ac...', '23'),
#  ('ac...', '23', 'NaN'),
#  ('23', 'NaN', '24'),
#  ('NaN', '24', 'NaN'),
#  ('24', 'NaN', '25'),
#  ('NaN', '25', 'NaN'),
#  ('25', 'NaN', '26'),
#  ('NaN', '26', 'l'),
#  ('26', 'l', 'That'),
#  ('l', 'That', 'thousand'),
#  ('That', 'thousand', 'ya'),
#  ('thousand', 'ya', '27'),
#  ('ya', '27', 'NaN'),
#  ('27', 'NaN', '28'),
#  ('NaN', '28', 'NaN'),
#  ('28', 'NaN', '29'),
#  ('NaN', '29', 'NaN'),
#  ('29', 'NaN', '..'),
#  ('NaN', '..', '...'),
#  ('..', '...', '48'),
#  ('...', '48', 'NaN'),
#  ('48', 'NaN', '49'),
#  ('NaN', '49', 'NaN'),
#  ('49', 'NaN', '50'),
#  ('NaN', '50', 'NaN'),
#  ('50', 'NaN', '51'),
#  ('NaN', '51', 'NaN'),
#  ('51', 'NaN', '52'),
#  ('NaN', '52', 'NaN'),
#  ('52', 'NaN', '53'),
#  ('NaN', '53', 'o......\\n@MKBHD'),
#  ('53', 'o......\\n@MKBHD', "https://t.co/QbynjD4q2H'"),
#  ('o......\\n@MKBHD', "https://t.co/QbynjD4q2H'", '54'),
#  ("https://t.co/QbynjD4q2H'", '54', 'scientific'),
#  ('54', 'scientific', 'Fi'),
#  ('scientific', 'Fi', '55'),
#  ('Fi', '55', 'NaN'),
#  ('55', 'NaN', '56'),
#  ('NaN', '56', 'st)'),
#  ('56', 'st)', 'Folding'),
#  ('st)', 'Folding', 'Phone!'),
#  ('Folding', 'Phone!', 'https://t.co/jwDCcdHTQd'),
#  ('Phone!', 'https://t.co/jwDCcdHTQd', '-'),
#  ('https://t.co/jwDCcdHTQd', '-', 'R...'),
#  ('-', 'R...', '57'),
#  ('R...', '57', 'NaN'),
#  ('57', 'NaN', '58'),
#  ('NaN', '58', 'NaN'),
#  ('58', 'NaN', '59'),
#  ('NaN', '59', 'ies...'),
#  ('59', 'ies...', '\\nmentioning'),
#  ('ies...', '\\nmentioning', 'only'),
#  ('\\nmentioning', 'only', 'the'),
#  ('only', 'the', 'ones'),
#  ('the', 'ones', 'that'),
#  ('ones', 'that', 'a'),
#  ('that', 'a', '60'),
#  ('a', '60', 'ies'),
#  ('60', 'ies', '\\xf0\\x9f\\x92\\xab'),
#  ('ies', '\\xf0\\x9f\\x92\\xab', 'https://t.co/nogtkfLqj'),
#  ('\\xf0\\x9f\\x92\\xab', 'https://t.co/nogtkfLqj', '61'),
#  ('https://t.co/nogtkfLqj', '61', 'NaN'),
#  ('61', 'NaN', '62'),
#  ('NaN', '62', 'NaN'),
#  ('62', 'NaN', '63'),
#  ('NaN', '63', '_K'),
#  ('63', '_K', '64'),
#  ('_K', '64', 'shanaKT'),
#  ('64', 'shanaKT', 'But'),
#  ('shanaKT', 'But', 'you'),
#  ('But', 'you', 'look'),
#  ('you', 'look', 'good'),
#  ('look', 'good', 'with'),
#  ('good', 'with', 'it'),
#  ('with', 'it', '\\xf0\\x9f\\x98...'),
#  ('it', '\\xf0\\x9f\\x98...', '65'),
#  ('\\xf0\\x9f\\x98...', '65', 'name'),
#  ('65', 'name', 'and'),
#  ('name', 'and', 'whe'),
#  ('and', 'whe', '66'),
#  ('whe', '66', 's'),
#  ('66', 's', 'who'),
#  ('s', 'who', 'successfully'),
#  ('who', 'successfully', 'fought'),
#  ('successfully', 'fought', 'to'),
#  ('fought', 'to', 'end'),
#  ('to', 'end', '#India\\xe2\\x8...'),
#  ('end', '#India\\xe2\\x8...', '67'),
#  ('#India\\xe2\\x8...', '67', 'NaN'),
#  ('67', 'NaN', '68'),
#  ('NaN', '68', 'iyadhaa'),
#  ('68', 'iyadhaa', '69'),
#  ('iyadhaa', '69', 'NaN'),
#  ('69', 'NaN', '70'),
#  ('NaN', '70', 'ld'),
#  ('70', 'ld', "\\xf0\\x9f\\x92\\xab'"),
#  ('ld', "\\xf0\\x9f\\x92\\xab'", '71'),
#  ("\\xf0\\x9f\\x92\\xab'", '71', '_K'),
#  ('71', '_K', '72'),
#  ('_K', '72', 'NaN'),
#  ('72', 'NaN', '73'),
#  ('NaN', '73', 'NaN'),
#  ('73', 'NaN', '74'),
#  ('NaN', '74', 'NaN'),
#  ('74', 'NaN', '75'),
#  ('NaN', '75', 'powe'),
#  ('75', 'powe', '76'),
#  ('powe', '76', 'om'),
#  ('76', 'om', 'the'),
#  ('om', 'the', 'beginning...'),
#  ('the', 'beginning...', 'only'),
#  ('beginning...', 'only', 'then'),
#  ('only', 'then', 'it'),
#  ('then', 'it', 'will'),
#  ('it', 'will', 'make'),
#  ('will', 'make', 'sen...'),
#  ('make', 'sen...', '77'),
#  ('sen...', '77', 'e'),
#  ('77', 'e', 'punctu'),
#  ('e', 'punctu', '5'),
#  ('punctu', '5', 'hou'),
#  ('5', 'hou', '\\'),
#  ('hou', '\\', '0'),
#  ('\\', '0', 'day.'),
#  ('0', 'day.', 'Cong'),
#  ('day.', 'Cong', '1'),
#  ('Cong', '1', 'NaN'),
#  ('1', 'NaN', '2'),
#  ('NaN', '2', 'fans'),
#  ('2', 'fans', 'who'),
#  ('fans', 'who', 'came'),
#  ('who', 'came', 'in'),
#  ('came', 'in', 'huge'),
#  ('in', 'huge', 'numbe'),
#  ('huge', 'numbe', '3'),
#  ('numbe', '3', 'NaN'),
#  ('3', 'NaN', '4'),
#  ('NaN', '4', 'acte'),
#  ('4', 'acte', '5'),
#  ('acte', '5', 'e'),
#  ('5', 'e', 'the'),
#  ('e', 'the', 'futu'),
#  ('the', 'futu', '6'),
#  ('futu', '6', 'y.'),
#  ('6', 'y.', 'Chee'),
#  ('y.', 'Chee', '7'),
#  ('Chee', '7', 's'),
#  ('7', 's', '\\xf0\\x9f\\x92\\x91\\xe2\\x9d\\xa4'),
#  ('s', '\\xf0\\x9f\\x92\\x91\\xe2\\x9d\\xa4', 'https://t.co/GR...'),
#  ('\\xf0\\x9f\\x92\\x91\\xe2\\x9d\\xa4', 'https://t.co/GR...', '8'),
#  ('https://t.co/GR...', '8', 'NaN'),
#  ('8', 'NaN', '9'),
#  ('NaN', '9', 'NaN'),
#  ('9', 'NaN', '10'),
#  ('NaN', '10', 'NaN'),
#  ('10', 'NaN', '11'),
#  ('NaN', '11', 'NaN'),
#  ('11', 'NaN', '12'),
#  ('NaN', '12', 'NaN'),
#  ('12', 'NaN', '13'),
#  ('NaN', '13', "IQUS'"),
#  ('13', "IQUS'", '14'),
#  ("IQUS'", '14', 'NaN'),
#  ('14', 'NaN', '15'),
#  ('NaN', '15', 'NaN'),
#  ('15', 'NaN', '16'),
#  ('NaN', '16', 'c'),
#  ('16', 'c', '17'),
#  ('c', '17', 'k.'),
#  ('17', 'k.', "https://t.co/o22H1XdzHc'"),
#  ('k.', "https://t.co/o22H1XdzHc'", '18'),
#  ("https://t.co/o22H1XdzHc'", '18', 'ogn'),
#  ('18', 'ogn', '#basushanke'),
#  ('ogn', '#basushanke', '19'),
#  ('#basushanke', '19', 'ything'),
#  ('19', 'ything', 've'),
#  ('ything', 've', '20'),
#  ('ve', '20', 'op'),
#  ('20', 'op', '21'),
#  ('op', '21', 'oduces'),
#  ('21', 'oduces', 'the'),
#  ('oduces', 'the', 'sha'),
#  ('the', 'sha', '22'),
#  ('sha', '22', 'a'),
#  ('22', 'a', "hah'"),
#  ('a', "hah'", '23'),
#  ("hah'", '23', 'NaN'),
#  ('23', 'NaN', '24'),
#  ('NaN', '24', 'NaN'),
#  ('24', 'NaN', '25'),
#  ('NaN', '25', 'yRig'),
#  ('25', 'yRig', '@whatsinside'),
#  ('yRig', '@whatsinside', 'Eve'),
#  ('@whatsinside', 'Eve', '26'),
#  ('Eve', '26', 'd'),
#  ('26', 'd', 'sta'),
#  ('d', 'sta', '27'),
#  ('sta', '27', 'NaN'),
#  ('27', 'NaN', '28'),
#  ('NaN', '28', 'NaN'),
#  ('28', 'NaN', '29'),
#  ('NaN', '29', "y-on'"),
#  ('29', "y-on'", '..'),
#  ("y-on'", '..', '...'),
#  ('..', '...', '48'),
#  ('...', '48', 'NaN'),
#  ('48', 'NaN', '49'),
#  ('NaN', '49', 'NaN'),
#  ('49', 'NaN', '50'),
#  ('NaN', '50', 'NaN'),
#  ('50', 'NaN', '51'),
#  ('NaN', '51', 'NaN'),
#  ('51', 'NaN', '52'),
#  ('NaN', '52', 'NaN'),
#  ('52', 'NaN', '53'),
#  ('NaN', '53', 'NaN'),
#  ('53', 'NaN', '54'),
#  ('NaN', '54', "e'"),
#  ('54', "e'", '55'),
#  ("e'", '55', 'NaN'),
#  ('55', 'NaN', '56'),
#  ('NaN', '56', 'NaN'),
#  ('56', 'NaN', '57'),
#  ('NaN', '57', 'NaN'),
#  ('57', 'NaN', '58'),
#  ('NaN', '58', 'NaN'),
#  ('58', 'NaN', '59'),
#  ('NaN', '59', 'e'),
#  ('59', 'e', 'shot'),
#  ('e', 'shot', 'al'),
#  ('shot', 'al', '60'),
#  ('al', '60', "'"),
#  ('60', "'", '61'),
#  ("'", '61', 'y'),
#  ('61', 'y', 'guys'),
#  ('y', 'guys', 'I'),
#  ('guys', 'I', 'dozed'),
#  ('I', 'dozed', 'off'),
#  ('dozed', 'off', 'as'),
#  ('off', 'as', 'I'),
#  ('as', 'I', 'was'),
#  ('I', 'was', 'ti'),
#  ('was', 'ti', '62'),
#  ('ti', '62', 'NaN'),
#  ('62', 'NaN', '63'),
#  ('NaN', '63', 'ishna:'),
#  ('63', 'ishna:', '\\xf0\\x9f\\x98\\x8a'),
#  ('ishna:', '\\xf0\\x9f\\x98\\x8a', "https://t.co/4QbsUhdoQt'"),
#  ('\\xf0\\x9f\\x98\\x8a', "https://t.co/4QbsUhdoQt'", '64'),
#  ("https://t.co/4QbsUhdoQt'", '64', 'NaN'),
#  ('64', 'NaN', '65'),
#  ('NaN', '65', 'e'),
#  ('65', 'e', 'you'),
#  ('e', 'you', 'live...'),
#  ('you', 'live...', 'DM'),
#  ('live...', 'DM', 'it'),
#  ('DM', 'it', 'to'),
#  ('it', 'to', 'my'),
#  ('to', 'my', 'Insta\\xe2\\x80\\xa6'),
#  ('my', 'Insta\\xe2\\x80\\xa6', 'ht...'),
#  ('Insta\\xe2\\x80\\xa6', 'ht...', '66'),
#  ('ht...', '66', 'a'),
#  ('66', 'a', 'laws'),
#  ('a', 'laws', 'that'),
#  ('laws', 'that', 'c'),
#  ('that', 'c', '67'),
#  ('c', '67', 'NaN'),
#  ('67', 'NaN', '68'),
#  ('NaN', '68', 'shini'),
#  ('68', 'shini', '\\xe2\\x98\\xba\\xef\\xb8\\x8f\\xf0\\x9f\\x92\\xa4...'),
#  ('shini', '\\xe2\\x98\\xba\\xef\\xb8\\x8f\\xf0\\x9f\\x92\\xa4...', '69'),
#  ('\\xe2\\x98\\xba\\xef\\xb8\\x8f\\xf0\\x9f\\x92\\xa4...', '69', 'NaN'),
#  ('69', 'NaN', '70'),
#  ('NaN', '70', 'NaN'),
#  ('70', 'NaN', '71'),
#  ('NaN', '71', 'ishna'),
#  ('71', 'ishna', "https://t.co/SoNp02HG2Z'"),
#  ('ishna', "https://t.co/SoNp02HG2Z'", '72'),
#  ("https://t.co/SoNp02HG2Z'", '72', 'NaN'),
#  ('72', 'NaN', '73'),
#  ('NaN', '73', 'NaN'),
#  ('73', 'NaN', '74'),
#  ('NaN', '74', 'NaN'),
#  ('74', 'NaN', '75'),
#  ('NaN', '75', 'house'),
#  ('75', 'house', "\\xf0\\x9f\\x92\\xab'"),
#  ('house', "\\xf0\\x9f\\x92\\xab'", '76'),
#  ("\\xf0\\x9f\\x92\\xab'", '76', 'NaN'),
#  ('76', 'NaN', '77'),
#  ('NaN', '77', 'e'),
#  ('77', 'e', 'aainda'),
#  ('e', 'aainda', '?'),
#  ('aainda', '?', '@aadhavkk'),
#  ('?', '@aadhavkk', '\\xf0\\x9f\\x98\\x9d'),
#  ('@aadhavkk', '\\xf0\\x9f\\x98\\x9d', '#highp'),
#  ('\\xf0\\x9f\\x98\\x9d', '#highp', 's'),
#  ('#highp', 's', 'at'),
#  ('s', 'at', 'the'),
#  ('at', 'the', '@Wimbledon'),
#  ('the', '@Wimbledon', 'final'),
#  ('@Wimbledon', 'final', 'yeste'),
#  ('final', 'yeste', '\\'),
#  ('yeste', '\\', '0'),
#  ('\\', '0', 'atulations'),
#  ('0', 'atulations', '@englandc'),
#  ('atulations', '@englandc', '1'),
#  ('@englandc', '1', 'NaN'),
#  ('1', 'NaN', '2'),
#  ('NaN', '2', 's'),
#  ('2', 's', 'to'),
#  ('s', 'to', 'suppo'),
#  ('to', 'suppo', '3'),
#  ('suppo', '3', 'NaN'),
#  ('3', 'NaN', '4'),
#  ('NaN', '4', 'shown'),
#  ('4', 'shown', 'by'),
#  ('shown', 'by', 'the'),
#  ('by', 'the', 'boys'),
#  ('the', 'boys', '\\xf0\\x9f\\x92\\xaf\\xf0\\x9f\\x9...'),
#  ('boys', '\\xf0\\x9f\\x92\\xaf\\xf0\\x9f\\x9...', '5'),
#  ('\\xf0\\x9f\\x92\\xaf\\xf0\\x9f\\x9...', '5', 'e'),
#  ('5', 'e', 'gene'),
#  ('e', 'gene', '6'),
#  ('gene', '6', 's'),
#  ('6', 's', 'and'),
#  ('s', 'and', 'thank'),
#  ('and', 'thank', 'you'),
#  ('thank', 'you', 'fo'),
#  ('you', 'fo', '7'),
#  ('fo', '7', 'NaN'),
#  ('7', 'NaN', '8'),
#  ('NaN', '8', 'NaN'),
#  ('8', 'NaN', '9'),
#  ('NaN', '9', 'NaN'),
#  ('9', 'NaN', '10'),
#  ('NaN', '10', 'NaN'),
#  ('10', 'NaN', '11'),
#  ('NaN', '11', 'NaN'),
#  ('11', 'NaN', '12'),
#  ('NaN', '12', 'NaN'),
#  ('12', 'NaN', '13'),
#  ('NaN', '13', 'NaN'),
#  ('13', 'NaN', '14'),
#  ('NaN', '14', 'NaN'),
#  ('14', 'NaN', '15'),
#  ('NaN', '15', 'NaN'),
#  ('15', 'NaN', '16'),
#  ('NaN', '16', 'icket'),
#  ('16', 'icket', 'shoe'),
#  ('icket', 'shoe', 'fo'),
#  ('shoe', 'fo', '17'),
#  ('fo', '17', 'NaN'),
#  ('17', 'NaN', '18'),
#  ('NaN', '18', '@vijayshanka'),
#  ('18', '@vijayshanka', '19'),
#  ('@vijayshanka', '19', 'y'),
#  ('19', 'y', 'se'),
#  ('y', 'se', '20'),
#  ('se', '20', 'eally'),
#  ('20', 'eally', 'does'),
#  ('eally', 'does', '21'),
#  ('does', '21', 'pest'),
#  ('21', 'pest', "image'"),
#  ('pest', "image'", '22'),
#  ("image'", '22', 'NaN'),
#  ('22', 'NaN', '23'),
#  ('NaN', '23', 'NaN'),
#  ('23', 'NaN', '24'),
#  ('NaN', '24', 'NaN'),
#  ('24', 'NaN', '25'),
#  ('NaN', '25', 'yone'),
#  ('25', 'yone', 'knows'),
#  ('yone', 'knows', 'Tacomas'),
#  ('knows', 'Tacomas', 'neve'),
#  ('Tacomas', 'neve', '26'),
#  ('neve', '26', 'e'),
#  ('26', 'e', 'on'),
#  ('e', 'on', 'Mac'),
#  ('on', 'Mac', '(to'),
#  ('Mac', '(to', 'the'),
#  ('(to', 'the', 't'),
#  ('the', 't', '27'),
#  ('t', '27', 'NaN'),
#  ('27', 'NaN', '28'),
#  ('NaN', '28', 'NaN'),
#  ('28', 'NaN', '29'),
#  ('NaN', '29', 'NaN'),
#  ('29', 'NaN', '..'),
#  ('NaN', '..', '...'),
#  ('..', '...', '48'),
#  ('...', '48', 'NaN'),
#  ('48', 'NaN', '49'),
#  ('NaN', '49', 'NaN'),
#  ('49', 'NaN', '50'),
#  ('NaN', '50', 'NaN'),
#  ('50', 'NaN', '51'),
#  ('NaN', '51', 'NaN'),
#  ('51', 'NaN', '52'),
#  ('NaN', '52', 'NaN'),
#  ('52', 'NaN', '53'),
#  ('NaN', '53', 'NaN'),
#  ('53', 'NaN', '54'),
#  ('NaN', '54', 'NaN'),
#  ('54', 'NaN', '55'),
#  ('NaN', '55', 'NaN'),
#  ('55', 'NaN', '56'),
#  ('NaN', '56', 'NaN'),
#  ('56', 'NaN', '57'),
#  ('NaN', '57', 'NaN'),
#  ('57', 'NaN', '58'),
#  ('NaN', '58', 'NaN'),
#  ('58', 'NaN', '59'),
#  ('NaN', '59', 'eady'),
#  ('59', 'eady', '\\xf0\\x9f\\x92\\xab'),
#  ('eady', '\\xf0\\x9f\\x92\\xab', "https://t.co/9S93sSkqS3'"),
#  ('\\xf0\\x9f\\x92\\xab', "https://t.co/9S93sSkqS3'", '60'),
#  ("https://t.co/9S93sSkqS3'", '60', 'NaN'),
#  ('60', 'NaN', '61'),
#  ('NaN', '61', 'ed'),
#  ('61', 'ed', 'f'),
#  ('ed', 'f', '62'),
#  ('f', '62', 'NaN'),
#  ('62', 'NaN', '63'),
#  ('NaN', '63', 'NaN'),
#  ('63', 'NaN', '64'),
#  ('NaN', '64', 'NaN'),
#  ('64', 'NaN', '65'),
#  ('NaN', '65', "nDs'"),
#  ('65', "nDs'", '66'),
#  ("nDs'", '66', 'iminalized'),
#  ('66', 'iminalized', 'same-sex'),
#  ('iminalized', 'same-sex', '67'),
#  ('same-sex', '67', 'NaN'),
#  ('67', 'NaN', '68'),
#  ('NaN', '68', 'NaN'),
#  ('68', 'NaN', '69'),
#  ('NaN', '69', 'NaN'),
#  ('69', 'NaN', '70'),
#  ('NaN', '70', 'NaN'),
#  ('70', 'NaN', '71'),
#  ('NaN', '71', 'NaN'),
#  ('71', 'NaN', '72'),
#  ('NaN', '72', 'NaN'),
#  ('72', 'NaN', '73'),
#  ('NaN', '73', 'NaN'),
#  ('73', 'NaN', '74'),
#  ('NaN', '74', 'NaN'),
#  ('74', 'NaN', '75'),
#  ('NaN', '75', 'NaN'),
#  ('75', 'NaN', '76'),
#  ('NaN', '76', 'NaN'),
#  ('76', 'NaN', '77'),
#  ('NaN', '77', 'iestess'),
#  ('77', 'iestess', "https://t.co/9obWEmGECm'"),
#  ('iestess', "https://t.co/9obWEmGECm'", 'day.'),
#  ("https://t.co/9obWEmGECm'", 'day.', 'Shee'),
#  ('day.', 'Shee', '\\'),
#  ('Shee', '\\', '0'),
#  ('\\', '0', 'icket.'),
#  ('0', 'icket.', "\\xf0\\x9f\\x91\\x8d\\xf0\\x9f\\x8f\\xbc'"),
#  ('icket.', "\\xf0\\x9f\\x91\\x8d\\xf0\\x9f\\x8f\\xbc'", '1'),
#  ("\\xf0\\x9f\\x91\\x8d\\xf0\\x9f\\x8f\\xbc'", '1', 'NaN'),
#  ('1', 'NaN', '2'),
#  ('NaN', '2', 't'),
#  ('2', 't', 'the'),
#  ('t', 'the', 'team.'),
#  ('the', 'team.', 'You'),
#  ('team.', 'You', 'made'),
#  ('You', 'made', 'it'),
#  ('made', 'it', 'a'),
#  ('it', 'a', 'memo'),
#  ('a', 'memo', '3'),
#  ('memo', '3', 'NaN'),
#  ('3', 'NaN', '4'),
#  ('NaN', '4', 'NaN'),
#  ('4', 'NaN', '5'),
#  ('NaN', '5', 'ation'),
#  ('5', 'ation', 'is'),
#  ('ation', 'is', 'a'),
#  ('is', 'a', 'blessing.'),
#  ('a', 'blessing.', '\\xf0\\x9f\\x98\\x87'),
#  ('blessing.', '\\xf0\\x9f\\x98\\x87', 'https://...'),
#  ('\\xf0\\x9f\\x98\\x87', 'https://...', '6'),
#  ('https://...', '6', 'you'),
#  ('6', 'you', '7'),
#  ('you', '7', 'NaN'),
#  ('7', 'NaN', '8'),
#  ('NaN', '8', 'NaN'),
#  ('8', 'NaN', '9'),
#  ('NaN', '9', 'NaN'),
#  ('9', 'NaN', '10'),
#  ('NaN', '10', 'NaN'),
#  ('10', 'NaN', '11'),
#  ('NaN', '11', 'NaN'),
#  ('11', 'NaN', '12'),
#  ('NaN', '12', 'NaN'),
#  ('12', 'NaN', '13'),
#  ('NaN', '13', 'NaN'),
#  ('13', 'NaN', '14'),
#  ('NaN', '14', 'NaN'),
#  ('14', 'NaN', '15'),
#  ('NaN', '15', 'NaN'),
#  ('15', 'NaN', '16'),
#  ('NaN', '16', 'you'),
#  ('16', 'you', 'inspi'),
#  ('you', 'inspi', '17'),
#  ('inspi', '17', 'NaN'),
#  ('17', 'NaN', '18'),
#  ('NaN', '18', '260'),
#  ('18', '260', "https://t.co/ppc0tHJ1FB'"),
#  ('260', "https://t.co/ppc0tHJ1FB'", '19'),
#  ("https://t.co/ppc0tHJ1FB'", '19', "iously'"),
#  ('19', "iously'", '20'),
#  ("iously'", '20', 'uin'),
#  ('20', 'uin', 'its'),
#  ('uin', 'its', 'chances'),
#  ('its', 'chances', 'as'),
#  ('chances', 'as', 'a'),
#  ('as', 'a', 'vlog'),
#  ('a', 'vlog', 'came'),
#  ('vlog', 'came', '21'),
#  ('came', '21', 'NaN'),
#  ('21', 'NaN', '22'),
#  ('NaN', '22', 'NaN'),
#  ('22', 'NaN', '23'),
#  ('NaN', '23', 'NaN'),
#  ('23', 'NaN', '24'),
#  ('NaN', '24', 'NaN'),
#  ('24', 'NaN', '25'),
#  ('NaN', '25', 'have'),
#  ('25', 'have', 'p'),
#  ('have', 'p', '26'),
#  ('p', '26', 'eats'),
#  ('26', 'eats', 'behind'),
#  ('eats', 'behind', 'the'),
#  ('behind', 'the', 'came'),
#  ('the', 'came', '27'),
#  ('came', '27', 'NaN'),
#  ('27', 'NaN', '28'),
#  ('NaN', '28', 'NaN'),
#  ('28', 'NaN', '29'),
#  ('NaN', '29', 'NaN'),
#  ('29', 'NaN', '..'),
#  ('NaN', '..', '...'),
#  ('..', '...', '48'),
#  ('...', '48', 'NaN'),
#  ('48', 'NaN', '49'),
#  ('NaN', '49', 'NaN'),
#  ('49', 'NaN', '50'),
#  ('NaN', '50', 'NaN'),
#  ('50', 'NaN', '51'),
#  ('NaN', '51', 'NaN'),
#  ('51', 'NaN', '52'),
#  ('NaN', '52', 'NaN'),
#  ('52', 'NaN', '53'),
#  ('NaN', '53', 'NaN'),
#  ('53', 'NaN', '54'),
#  ('NaN', '54', 'NaN'),
#  ('54', 'NaN', '55'),
#  ('NaN', '55', 'NaN'),
#  ('55', 'NaN', '56'),
#  ('NaN', '56', 'NaN'),
#  ('56', 'NaN', '57'),
#  ('NaN', '57', 'NaN'),
#  ('57', 'NaN', '58'),
#  ('NaN', '58', 'NaN'),
#  ...]
